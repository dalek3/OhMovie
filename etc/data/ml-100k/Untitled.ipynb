# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from pyfm import pylibfm

# Read in data
def loadData(filename,path="./"):
    data = []
    y = []
    users=set()
    items=set()
    with open(path+filename) as f:
        for line in f:
            (user,movieid,rating,ts)=line.split('\t')
            data.append({ "user_id": str(user), "movie_id": str(movieid)})
            y.append(float(rating))
            users.add(user)
            items.add(movieid)

    return (data, np.array(y), users, items)

(train_data, y_train, train_users, train_items) = loadData("ua.base")
(test_data, y_test, test_users, test_items) = loadData("ua.test")
v = DictVectorizer()
X_train = v.fit_transform(train_data)
X_test = v.transform(test_data)

# Build and train a Factorization Machine
fm = pylibfm.FM(num_factors=10, num_iter=100, verbose=True, task="regression", initial_learning_rate=0.001, learning_rate_schedule="optimal")

fm.fit(X_train,y_train)

# Evaluate
preds = fm.predict(X_test)
from sklearn.metrics import mean_squared_error
print("FM MSE: %.4f" % mean_squared_error(y_test,preds))
# Out:
# Creating validation dataset of 0.01 of training for adaptive regularization
# -- Epoch 1
# Training MSE: 0.59527
# -- Epoch 2
# Training MSE: 0.51804
# -- Epoch 3
# Training MSE: 0.49042
# -- Epoch 4
# Training MSE: 0.47460
# -- Epoch 5
# Training MSE: 0.46424
# -- Epoch 6
# Training MSE: 0.45674
# -- Epoch 7
# Training MSE: 0.45089
# -- Epoch 8
# Training MSE: 0.44647
# -- Epoch 9
# Training MSE: 0.44267
# -- Epoch 10
# Training MSE: 0.43947
# -- Epoch 11
# Training MSE: 0.43667
# -- Epoch 12
# Training MSE: 0.43437
# -- Epoch 13
# Training MSE: 0.43221
# -- Epoch 14
# Training MSE: 0.43022
# -- Epoch 15
# Training MSE: 0.42854
# -- Epoch 16
# Training MSE: 0.42681
# -- Epoch 17
# Training MSE: 0.42530
# -- Epoch 18
# Training MSE: 0.42393
# -- Epoch 19
# Training MSE: 0.42261
# -- Epoch 20
# Training MSE: 0.42123
# -- Epoch 21
# Training MSE: 0.42008
# -- Epoch 22
# Training MSE: 0.41880
# -- Epoch 23
# Training MSE: 0.41752
# -- Epoch 24
# Training MSE: 0.41635
# -- Epoch 25
# Training MSE: 0.41515
# -- Epoch 26
# Training MSE: 0.41391
# -- Epoch 27
# Training MSE: 0.41276
# -- Epoch 28
# Training MSE: 0.41148
# -- Epoch 29
# Training MSE: 0.41026
# -- Epoch 30
# Training MSE: 0.40880
# -- Epoch 31
# Training MSE: 0.40757
# -- Epoch 32
# Training MSE: 0.40613
# -- Epoch 33
# Training MSE: 0.40469
# -- Epoch 34
# Training MSE: 0.40329
# -- Epoch 35
# Training MSE: 0.40174
# -- Epoch 36
# Training MSE: 0.40022
# -- Epoch 37
# Training MSE: 0.39861
# -- Epoch 38
# Training MSE: 0.39695
# -- Epoch 39
# Training MSE: 0.39525
# -- Epoch 40
# Training MSE: 0.39342
# -- Epoch 41
# Training MSE: 0.39147
# -- Epoch 42
# Training MSE: 0.38970
# -- Epoch 43
# Training MSE: 0.38778
# -- Epoch 44
# Training MSE: 0.38580
# -- Epoch 45
# Training MSE: 0.38374
# -- Epoch 46
# Training MSE: 0.38167
# -- Epoch 47
# Training MSE: 0.37968
# -- Epoch 48
# Training MSE: 0.37759
# -- Epoch 49
# Training MSE: 0.37542
# -- Epoch 50
# Training MSE: 0.37334
# -- Epoch 51
# Training MSE: 0.37124
# -- Epoch 52
# Training MSE: 0.36913
# -- Epoch 53
# Training MSE: 0.36700
# -- Epoch 54
# Training MSE: 0.36494
# -- Epoch 55
# Training MSE: 0.36293
# -- Epoch 56
# Training MSE: 0.36096
# -- Epoch 57
# Training MSE: 0.35898
# -- Epoch 58
# Training MSE: 0.35704
# -- Epoch 59
# Training MSE: 0.35503
# -- Epoch 60
# Training MSE: 0.35334
# -- Epoch 61
# Training MSE: 0.35152
# -- Epoch 62
# Training MSE: 0.34975
# -- Epoch 63
# Training MSE: 0.34811
# -- Epoch 64
# Training MSE: 0.34640
# -- Epoch 65
# Training MSE: 0.34484
# -- Epoch 66
# Training MSE: 0.34339
# -- Epoch 67
# Training MSE: 0.34195
# -- Epoch 68
# Training MSE: 0.34060
# -- Epoch 69
# Training MSE: 0.33921
# -- Epoch 70
# Training MSE: 0.33790
# -- Epoch 71
# Training MSE: 0.33665
# -- Epoch 72
# Training MSE: 0.33548
# -- Epoch 73
# Training MSE: 0.33434
# -- Epoch 74
# Training MSE: 0.33336
# -- Epoch 75
# Training MSE: 0.33228
# -- Epoch 76
# Training MSE: 0.33141
# -- Epoch 77
# Training MSE: 0.33050
# -- Epoch 78
# Training MSE: 0.32957
# -- Epoch 79
# Training MSE: 0.32881
# -- Epoch 80
# Training MSE: 0.32803
# -- Epoch 81
# Training MSE: 0.32729
# -- Epoch 82
# Training MSE: 0.32656
# -- Epoch 83
# Training MSE: 0.32604
# -- Epoch 84
# Training MSE: 0.32544
# -- Epoch 85
# Training MSE: 0.32488
# -- Epoch 86
# Training MSE: 0.32440
# -- Epoch 87
# Training MSE: 0.32396
# -- Epoch 88
# Training MSE: 0.32343
# -- Epoch 89
# Training MSE: 0.32305
# -- Epoch 90
# Training MSE: 0.32265
# -- Epoch 91
# Training MSE: 0.32234
# -- Epoch 92
# Training MSE: 0.32199
# -- Epoch 93
# Training MSE: 0.32167
# -- Epoch 94
# Training MSE: 0.32138
# -- Epoch 95
# Training MSE: 0.32117
# -- Epoch 96
# Training MSE: 0.32094
# -- Epoch 97
# Training MSE: 0.32071
# -- Epoch 98
# Training MSE: 0.32046
# -- Epoch 99
# Training MSE: 0.32025
# -- Epoch 100
# Training MSE: 0.32016
# FM MSE: 0.8878

# %%
import pyfm.
